# %%
from bs4 import BeautifulSoup
import requests

# %% [raw]
# url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area"

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area"

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries and dependencies by area - Wikipedia</title>
# ...

# %%
soup.find_all('table')[1]
# Out:
# <table class="wikitable sortable" style="text-align:right">
# <tbody><tr class="is-sticky">
# <th></th>
# <th style="width:18em">Country / dependency
# </th>
# <th data-sort-type="number" style="width:9.7em">Total<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number" style="width:9.7em">Land<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number" style="width:7.5em">Water<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number">%<br/>water</th>
# <th class="unsortable">
# </th></tr>
# <tr>
# <td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –</td>
# <td style="text-align:left"><b><a href="/wiki/Earth" title="Earth">Earth</a></b></td>
# <td>510,072,000 (196,940,000)</td>
# <td>148,940,000 (57,506,000)</td>
# <td>361,132,000 (139,434,000)</td>
# <td>70.8</td>
# <td>
# </td></tr>
# <tr>
# <td><span data-sort-value="7000100000000000000♠">1</span></td>
# ...

# %%
soup.find_all('table', class_ = 'wikitable sortable')
# Out:
# [<table class="wikitable sortable" style="text-align:right">
#  <tbody><tr class="is-sticky">
#  <th></th>
#  <th style="width:18em">Country / dependency
#  </th>
#  <th data-sort-type="number" style="width:9.7em">Total<br/>in km<sup>2</sup> (mi<sup>2</sup>)
#  </th>
#  <th data-sort-type="number" style="width:9.7em">Land<br/>in km<sup>2</sup> (mi<sup>2</sup>)
#  </th>
#  <th data-sort-type="number" style="width:7.5em">Water<br/>in km<sup>2</sup> (mi<sup>2</sup>)
#  </th>
#  <th data-sort-type="number">%<br/>water</th>
#  <th class="unsortable">
#  </th></tr>
#  <tr>
#  <td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –</td>
#  <td style="text-align:left"><b><a href="/wiki/Earth" title="Earth">Earth</a></b></td>
#  <td>510,072,000 (196,940,000)</td>
#  <td>148,940,000 (57,506,000)</td>
#  <td>361,132,000 (139,434,000)</td>
#  <td>70.8</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td><span data-sort-value="7000100000000000000♠">1</span></td>
# ...

# %%
<table class="wikitable sortable jquery-tablesorter">
<caption>
# Out:
#   Cell In[81], line 1
#     <table class="wikitable sortable jquery-tablesorter">
#     ^
# SyntaxError: invalid syntax

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable" style="text-align:right">
# <tbody><tr class="is-sticky">
# <th></th>
# <th style="width:18em">Country / dependency
# </th>
# <th data-sort-type="number" style="width:9.7em">Total<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number" style="width:9.7em">Land<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number" style="width:7.5em">Water<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number">%<br/>water</th>
# <th class="unsortable">
# </th></tr>
# <tr>
# <td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –</td>
# <td style="text-align:left"><b><a href="/wiki/Earth" title="Earth">Earth</a></b></td>
# <td>510,072,000 (196,940,000)</td>
# <td>148,940,000 (57,506,000)</td>
# <td>361,132,000 (139,434,000)</td>
# <td>70.8</td>
# <td>
# </td></tr>
# <tr>
# <td><span data-sort-value="7000100000000000000♠">1</span></td>
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th></th>,
#  <th style="width:18em">Country / dependency
#  </th>,
#  <th data-sort-type="number" style="width:9.7em">Total<br/>in km<sup>2</sup> (mi<sup>2</sup>)
#  </th>,
#  <th data-sort-type="number" style="width:9.7em">Land<br/>in km<sup>2</sup> (mi<sup>2</sup>)
#  </th>,
#  <th data-sort-type="number" style="width:7.5em">Water<br/>in km<sup>2</sup> (mi<sup>2</sup>)
#  </th>,
#  <th data-sort-type="number">%<br/>water</th>,
#  <th class="unsortable">
#  </th>]

# %%
world_table_titles = [titles.text.strip() for titles in world_titles]

print(world_table_titles)
# Out:
# ['', 'Country / dependency', 'Totalin km2 (mi2)', 'Landin km2 (mi2)', 'Waterin km2 (mi2)', '%water', '']

# %%
world_table_titles
# Out:
# ['',
#  'Country / dependency',
#  'Totalin km2 (mi2)',
#  'Landin km2 (mi2)',
#  'Waterin km2 (mi2)',
#  '%water',
#  '']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [, Country / dependency, Totalin km2 (mi2), Landin km2 (mi2), Waterin km2 (mi2), %water, ]
# Index: []

# %%
#NOW WE HAVE TO PULL IN DATA

# %%
column_data = table.find_all('tr')

# %%
#loop through it (look up strip function )
#for row in column_data[1: ]:
 #   row_data = row.find_all('td')
  #  individual_row_data = [data.text.strip() for data in row_data]
   # print(individual_row_data)
    
    #length = len(df)
    #df.loc[length] = individual_row_data

# %%
 print(individual_row_data)
# Out:
# ['195', 'Vatican City', '0.49 (0.19)', '0.49 (0.19)', '0', '0', '[dq]']

# %%
import numpy as np

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    if len(individual_row_data) != len(df.columns):
        print("Mismatched number of columns for this row:", individual_row_data)
# Out:
# Mismatched number of columns for this row: ['United States', '9,833,517 (3,796,741)', '9,147,593 (3,531,904)', '685,924 (264,837)', '7.0', '[g]']
# Mismatched number of columns for this row: ['40', 'Afghanistan', '652,867 (252,073)', '652,867 (252,073)', '0', '0']

# %%
#for row in column_data[1: ]:
 #   row_data = row.find_all('td')
  #  individual_row_data = [data.text.strip() for data in row_data]
   # print(individual_row_data)
    
    #length = len(df)
    #df.loc[length] = individual_row_data

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    if len(individual_row_data) != len(df.columns):
        # Fill missing columns with NaN
        while len(individual_row_data) < len(df.columns):
            individual_row_data.append(np.nan)
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                    Country / dependency  \
# 0            –                                    Earth
# 1            1                                   Russia
# 2            –                               Antarctica
# 3            2                                   Canada
# 4    3 or 4[e]                                    China
# ..         ...                                      ...
# 260          –  Ashmore and Cartier Islands (Australia)
# 261          –               Spratly Islands (disputed)
# 262          –            Coral Sea Islands (Australia)
# 263        194                                   Monaco
# 264        195                             Vatican City
#
#              Totalin km2 (mi2)          Landin km2 (mi2)  \
# 0    510,072,000 (196,940,000)  148,940,000 (57,506,000)
# 1       17,098,246 (6,601,667)    16,378,410 (6,323,737)
# 2       14,200,000 (5,480,000)    14,200,000 (5,480,000)
# 3        9,984,670 (3,855,100)     9,093,507 (3,511,021)
# ...

# %% [markdown]
# # Clean Table
#     #remove 12q12

# %%
#drop the last column of dataframe
df = df.iloc[:,:-1]
df
# Out:
#                                    Country / dependency  \
# 0            –                                    Earth
# 1            1                                   Russia
# 2            –                               Antarctica
# 3            2                                   Canada
# 4    3 or 4[e]                                    China
# ..         ...                                      ...
# 260          –  Ashmore and Cartier Islands (Australia)
# 261          –               Spratly Islands (disputed)
# 262          –            Coral Sea Islands (Australia)
# 263        194                                   Monaco
# 264        195                             Vatican City
#
#              Totalin km2 (mi2)          Landin km2 (mi2)  \
# 0    510,072,000 (196,940,000)  148,940,000 (57,506,000)
# 1       17,098,246 (6,601,667)    16,378,410 (6,323,737)
# 2       14,200,000 (5,480,000)    14,200,000 (5,480,000)
# 3        9,984,670 (3,855,100)     9,093,507 (3,511,021)
# ...

# %% [markdown]
# # Rename column

# %%
df = df.rename(columns = { 'Totalin km2 (mi2)' : 'Total in km2 (mi2)', 
                     'Landin km2 (mi2)' : 'Land in km2 (mi2)', 
                     'Waterin km2 (mi2)' : 'Water in km2 (mi2',
                    '%water' : 'Water (%)'})

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 260    False
# 261    False
# 262    False
# 263    False
# 264    False
# Length: 265, dtype: bool

# %%
#i'm chosing to remove the [e] like this because i do know 
#that their are only 2 [e] in this column howver if i wanted to remove others 
#i would consider using a method that would assist in removing characters that come 
#after []

df[''] = df[''].str.rstrip('[e]')
# Out:
# /var/folders/kb/ft51qq752cx54wl3ts5jb8jc0000gn/T/ipykernel_11183/839983681.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[''] = df[''].str.rstrip('[e]')

# %%
#tidy up 

df.sort_values('')
# Out:
#                    Country / dependency          Totalin km2 (mi2)  \
# 1      1                         Russia     17,098,246 (6,601,667)
# 11    10                        Algeria        2,381,741 (919,595)
# 107  100                          Benin           114,763 (44,310)
# 108  101                       Honduras           112,492 (43,433)
# 109  102                        Liberia           111,369 (43,000)
# ..   ...                            ...                        ...
# 197    –  Turks and Caicos Islands (UK)                  948 (366)
# 195    –        Faroe Islands (Denmark)                1,393 (538)
# 194    –                Åland (Finland)                1,580 (610)
# 189    –              Hong Kong (China)              2,755 (1,064)
# 0      –                          Earth  510,072,000 (196,940,000)
#
#              Landin km2 (mi2)          Waterin km2 (mi2) %water
# 1      16,378,410 (6,323,737)          719,836 (277,930)    4.2
# ...

# %%
df
# Out:
#                                 Country / dependency  \
# 0         –                                    Earth
# 1         1                                   Russia
# 2         –                               Antarctica
# 3         2                                   Canada
# 4    3 or 4                                    China
# ..      ...                                      ...
# 260       –  Ashmore and Cartier Islands (Australia)
# 261       –               Spratly Islands (disputed)
# 262       –            Coral Sea Islands (Australia)
# 263     194                                   Monaco
# 264     195                             Vatican City
#
#             Total in km2 (mi2)         Land in km2 (mi2)  \
# 0    510,072,000 (196,940,000)  148,940,000 (57,506,000)
# 1       17,098,246 (6,601,667)    16,378,410 (6,323,737)
# 2       14,200,000 (5,480,000)    14,200,000 (5,480,000)
# 3        9,984,670 (3,855,100)     9,093,507 (3,511,021)
# ...

# %%
df.to_csv(r'/Users/sierrawhonder/Desktop/Countries.csv')
